# %%
import pandas as pd 
import numpy as np 
import sys
import os
sys.path.append("..")

from my_modules import my_functions as mybib


# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
files_list = os.listdir('../data/input/road_accidents_germany')
files_list
# Out:
# ['Unfallorte2018_LinRef.txt',
#  'Unfallorte2019_LinRef.txt',
#  'Unfallorte2020_LinRef.csv',
#  'Unfallorte2021_LinRef.csv',
#  'Unfallorte2022_LinRef.csv']

# %%
column_occurerences = {}
final_dataframes_list = []

for file in files_list:
    with open(f"../data/input/road_accidents_germany/{file}", 'r') as f:
        data = pd.read_csv(f,  encoding = 'ISO-8859-1', delimiter = ";")


            
        column_name_mapping = {
            'OBJECTID_1': 'OBJECTID',
            'USTRZUSTAND': 'STRZUSTAND',
            'IstSonstig' : 'IstSonstige',
            'IstStrassenzustand': 'STRZUSTAND',
            'XGCSWGS84' : 'Longitude',
            'YGCSWGS84' : 'Latitude'
            
        }
        
        missing_column = 'UIDENTSTLAE'
        
        column_order = ['OBJECTID', 'UIDENTSTLAE', 'ULAND', 'UREGBEZ', 'UKREIS', 'UGEMEINDE',
       'UJAHR', 'UMONAT', 'USTUNDE', 'UWOCHENTAG', 'UKATEGORIE', 'UART',
       'UTYP1', 'ULICHTVERH', 'STRZUSTAND', 'IstRad', 'IstPKW', 'IstFuss',
       'IstKrad', 'IstGkfz', 'IstSonstige', 'LINREFX', 'LINREFY', 'Longitude',
       'Latitude']

        data.rename(columns={col: column_name_mapping[col] for col in data.columns if col in column_name_mapping}, inplace=True)
        
      

        
        if missing_column not in data.columns:
            # Add the missing column with the default value
            data[missing_column] = None
            
        data = data[column_order]
        
        for column in data.columns:
            column_occurerences[column] = column_occurerences.get(column, 0) + 1  
        
        if data['UIDENTSTLAE'].dtype == 'float64':
        
            data['UIDENTSTLAE'] = data['UIDENTSTLAE'].apply(lambda x: f"{x:.0f}")
            data['UIDENTSTLAE'] = data['UIDENTSTLAE'].astype(str)
        data['Longitude'] = data['Longitude'].str.replace(',', '.').astype(float)
        data['Latitude'] = data['Latitude'].str.replace(',', '.').astype(float)


        # compare column names and dtypes before combine data set
        display(data.head(2))
        display(data.shape)        
        display(data.columns)
        display(data.dtypes)
        
        final_dataframes_list.append(data)      
        
for column, count in column_occurerences.items():
    print(f"{column}: {count}")
    
final_df = pd.concat(final_dataframes_list, ignore_index=True)
final_df.insert(0, 'NEW_OBJECTID', final_df.index) 


berlin_brandenb_df = final_df[final_df['ULAND'].isin([11,12])]
# Out:
#    OBJECTID UIDENTSTLAE  ULAND  UREGBEZ  UKREIS  UGEMEINDE  UJAHR  UMONAT  \
# 0         1        None      1        0       3          0   2018       1
# 1         2        None      1        0      62         20   2018       1
#
#    USTUNDE  UWOCHENTAG  ...  IstRad  IstPKW  IstFuss  IstKrad  IstGkfz  \
# 0        8           5  ...       1       0        0        0        0
# 1       15           6  ...       0       1        0        0        0
#
#    IstSonstige                 LINREFX                  LINREFY  Longitude  \
# 0            0  612054,341999999950000  5969634,006000000100000  10.703950
# 1            0  592301,984999999990000  5938800,026999999800000  10.394497
#
#     Latitude
# 0  53.863081
# 1  53.589906
#
# [2 rows x 25 columns]
# (211868, 25)
# Index(['OBJECTID', 'UIDENTSTLAE', 'ULAND', 'UREGBEZ', 'UKREIS', 'UGEMEINDE',
#        'UJAHR', 'UMONAT', 'USTUNDE', 'UWOCHENTAG', 'UKATEGORIE', 'UART',
#        'UTYP1', 'ULICHTVERH', 'STRZUSTAND', 'IstRad', 'IstPKW', 'IstFuss',
#        'IstKrad', 'IstGkfz', 'IstSonstige', 'LINREFX', 'LINREFY', 'Longitude',
#        'Latitude'],
#       dtype='object')
# OBJECTID         int64
# UIDENTSTLAE     object
# ULAND            int64
# UREGBEZ          int64
# UKREIS           int64
# UGEMEINDE        int64
# UJAHR            int64
# UMONAT           int64
# USTUNDE          int64
# UWOCHENTAG       int64
# UKATEGORIE       int64
# UART             int64
# UTYP1            int64
# ULICHTVERH       int64
# STRZUSTAND       int64
# IstRad           int64
# IstPKW           int64
# IstFuss          int64
# IstKrad          int64
# IstGkfz          int64
# IstSonstige      int64
# LINREFX         object
# LINREFY         object
# Longitude      float64
# Latitude       float64
# dtype: object
#    OBJECTID UIDENTSTLAE  ULAND  UREGBEZ  UKREIS  UGEMEINDE  UJAHR  UMONAT  \
# 0         1        None      1        0      57         25   2019       1
# 1         2        None      1        0       3          0   2019       1
#
#    USTUNDE  UWOCHENTAG  ...  IstRad  IstPKW  IstFuss  IstKrad  IstGkfz  \
# 0        5           5  ...       0       1        0        0        0
# 1        6           2  ...       1       1        0        0        0
#
#    IstSonstige                 LINREFX                  LINREFY  Longitude  \
# 0            0  579075,960927323440000  6023531,318255106000000  10.216714
# 1            0  611914,920398440210000  5968419,523143058600000  10.701388
#
#    Latitude
# 0  54.35346
# 1  53.85220
#
# [2 rows x 25 columns]
# (268370, 25)
# Index(['OBJECTID', 'UIDENTSTLAE', 'ULAND', 'UREGBEZ', 'UKREIS', 'UGEMEINDE',
#        'UJAHR', 'UMONAT', 'USTUNDE', 'UWOCHENTAG', 'UKATEGORIE', 'UART',
#        'UTYP1', 'ULICHTVERH', 'STRZUSTAND', 'IstRad', 'IstPKW', 'IstFuss',
#        'IstKrad', 'IstGkfz', 'IstSonstige', 'LINREFX', 'LINREFY', 'Longitude',
#        'Latitude'],
#       dtype='object')
# OBJECTID         int64
# UIDENTSTLAE     object
# ULAND            int64
# UREGBEZ          int64
# UKREIS           int64
# UGEMEINDE        int64
# UJAHR            int64
# UMONAT           int64
# USTUNDE          int64
# UWOCHENTAG       int64
# UKATEGORIE       int64
# UART             int64
# UTYP1            int64
# ULICHTVERH       int64
# STRZUSTAND       int64
# IstRad           int64
# IstPKW           int64
# IstFuss          int64
# IstKrad          int64
# IstGkfz          int64
# IstSonstige      int64
# LINREFX         object
# LINREFY         object
# Longitude      float64
# Latitude       float64
# dtype: object
#    OBJECTID           UIDENTSTLAE  ULAND  UREGBEZ  UKREIS  UGEMEINDE  UJAHR  \
# 0         1  12200116471201851392     12        0      68        468   2020
# 1         2  12200106642131830784     12        0      61        112   2020
#
#    UMONAT  USTUNDE  UWOCHENTAG  ...  IstRad  IstPKW  IstFuss  IstKrad  \
# 0       1       11           5  ...       0       0        0        0
# 1       1       17           2  ...       0       1        1        0
#
#    IstGkfz  IstSonstige                 LINREFX                  LINREFY  \
# 0        1            0  735840,436700000430000  5887204,801599999900000
# 1        0            0  814106,991899999790000  5811960,550300000200000
#
#    Longitude   Latitude
# 0  12.521519  53.082133
# 1  13.614609  52.367678
#
# [2 rows x 25 columns]
# (237994, 25)
# Index(['OBJECTID', 'UIDENTSTLAE', 'ULAND', 'UREGBEZ', 'UKREIS', 'UGEMEINDE',
#        'UJAHR', 'UMONAT', 'USTUNDE', 'UWOCHENTAG', 'UKATEGORIE', 'UART',
#        'UTYP1', 'ULICHTVERH', 'STRZUSTAND', 'IstRad', 'IstPKW', 'IstFuss',
#        'IstKrad', 'IstGkfz', 'IstSonstige', 'LINREFX', 'LINREFY', 'Longitude',
#        'Latitude'],
#       dtype='object')
# OBJECTID         int64
# UIDENTSTLAE     object
# ULAND            int64
# UREGBEZ          int64
# UKREIS           int64
# UGEMEINDE        int64
# UJAHR            int64
# UMONAT           int64
# USTUNDE          int64
# UWOCHENTAG       int64
# UKATEGORIE       int64
# UART             int64
# UTYP1            int64
# ULICHTVERH       int64
# STRZUSTAND       int64
# IstRad           int64
# IstPKW           int64
# IstFuss          int64
# IstKrad          int64
# IstGkfz          int64
# IstSonstige      int64
# LINREFX         object
# LINREFY         object
# Longitude      float64
# Latitude       float64
# dtype: object
# C:\Users\Domen\AppData\Local\Temp\ipykernel_11868\155376313.py:6: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(f,  encoding = 'ISO-8859-1', delimiter = ";")
#    OBJECTID          UIDENTSTLAE  ULAND  UREGBEZ  UKREIS  UGEMEINDE  UJAHR  \
# 0         1  1210308125013512021      1        0      54        165   2021
# 1         2  1210608134013112021      1        0       2          0   2021
#
#    UMONAT  USTUNDE  UWOCHENTAG  ...  IstRad  IstPKW  IstFuss  IstKrad  \
# 0       3        7           2  ...       0       1        0        0
# 1       6       15           3  ...       0       1        0        0
#
#    IstGkfz  IstSonstige                 LINREFX                  LINREFY  \
# 0        0            0  483995,394383990205824  6069091,089339181780815
# 1        0            0  573010,098060709424317  6020090,876354970037937
#
#    Longitude   Latitude
# 0   8.751233  54.768787
# 1  10.122558  54.323450
#
# [2 rows x 25 columns]
# (233208, 25)
# Index(['OBJECTID', 'UIDENTSTLAE', 'ULAND', 'UREGBEZ', 'UKREIS', 'UGEMEINDE',
#        'UJAHR', 'UMONAT', 'USTUNDE', 'UWOCHENTAG', 'UKATEGORIE', 'UART',
#        'UTYP1', 'ULICHTVERH', 'STRZUSTAND', 'IstRad', 'IstPKW', 'IstFuss',
#        'IstKrad', 'IstGkfz', 'IstSonstige', 'LINREFX', 'LINREFY', 'Longitude',
#        'Latitude'],
#       dtype='object')
# OBJECTID         int64
# UIDENTSTLAE     object
# ULAND            int64
# UREGBEZ          int64
# UKREIS           int64
# UGEMEINDE        int64
# UJAHR            int64
# UMONAT           int64
# USTUNDE          int64
# UWOCHENTAG       int64
# UKATEGORIE       int64
# UART             int64
# UTYP1            int64
# ULICHTVERH       int64
# STRZUSTAND       int64
# IstRad           int64
# IstPKW           int64
# IstFuss          int64
# IstKrad          int64
# IstGkfz          int64
# IstSonstige      int64
# LINREFX         object
# LINREFY         object
# Longitude      float64
# Latitude       float64
# dtype: object
# C:\Users\Domen\AppData\Local\Temp\ipykernel_11868\155376313.py:6: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(f,  encoding = 'ISO-8859-1', delimiter = ";")
#    OBJECTID          UIDENTSTLAE  ULAND  UREGBEZ  UKREIS  UGEMEINDE  UJAHR  \
# 0         1  1220204125013262022      1        0      54         84   2022
# 1         2  1220529134013152022      1        0      57         44   2022
#
#    UMONAT  USTUNDE  UWOCHENTAG  ...  IstRad  IstPKW  IstFuss  IstKrad  \
# 0       2       19           6  ...       1       1        0        0
# 1       5       11           1  ...       0       0        0        1
#
#    IstGkfz  IstSonstige                 LINREFX                  LINREFY  \
# 0        0            0  506085,644000001018867  6035085,351999809965491
# 1        0            0  593821,621226734016091  6014331,532445689663291
#
#    Longitude   Latitude
# 0   9.093886  54.463396
# 1  10.440636  54.268304
#
# [2 rows x 25 columns]
# (256492, 25)
# Index(['OBJECTID', 'UIDENTSTLAE', 'ULAND', 'UREGBEZ', 'UKREIS', 'UGEMEINDE',
#        'UJAHR', 'UMONAT', 'USTUNDE', 'UWOCHENTAG', 'UKATEGORIE', 'UART',
#        'UTYP1', 'ULICHTVERH', 'STRZUSTAND', 'IstRad', 'IstPKW', 'IstFuss',
#        'IstKrad', 'IstGkfz', 'IstSonstige', 'LINREFX', 'LINREFY', 'Longitude',
#        'Latitude'],
#       dtype='object')
# OBJECTID         int64
# UIDENTSTLAE     object
# ULAND            int64
# UREGBEZ          int64
# UKREIS           int64
# UGEMEINDE        int64
# UJAHR            int64
# UMONAT           int64
# USTUNDE          int64
# UWOCHENTAG       int64
# UKATEGORIE       int64
# UART             int64
# UTYP1            int64
# ULICHTVERH       int64
# STRZUSTAND       int64
# IstRad           int64
# IstPKW           int64
# IstFuss          int64
# IstKrad          int64
# IstGkfz          int64
# IstSonstige      int64
# LINREFX         object
# LINREFY         object
# Longitude      float64
# Latitude       float64
# dtype: object
# OBJECTID: 5
# UIDENTSTLAE: 5
# ULAND: 5
# UREGBEZ: 5
# UKREIS: 5
# UGEMEINDE: 5
# UJAHR: 5
# UMONAT: 5
# USTUNDE: 5
# UWOCHENTAG: 5
# UKATEGORIE: 5
# UART: 5
# UTYP1: 5
# ULICHTVERH: 5
# STRZUSTAND: 5
# IstRad: 5
# IstPKW: 5
# IstFuss: 5
# IstKrad: 5
# IstGkfz: 5
# IstSonstige: 5
# LINREFX: 5
# LINREFY: 5
# Longitude: 5
# Latitude: 5

# %%
berlin_brandenb_df
# Out:
#          NEW_OBJECTID  OBJECTID           UIDENTSTLAE  ULAND  UREGBEZ  UKREIS  \
# 59914           59914     59915                  None     12        0      72
# 59915           59915     59916                  None     12        0      71
# 59916           59916     59917                  None     12        0      67
# 59917           59917     59918                  None     12        0      64
# 59918           59918     59919                  None     12        0      71
# ...               ...       ...                   ...    ...      ...     ...
# 1195893       1195893    244454  12221223522702969070     12        0      53
# 1195896       1195896    244457  12221208662102936780     12        0      61
# 1195905       1195905    244466  12221220622203963240     12        0      52
# 1195908       1195908    244469  12221206722103933670     12        0      51
# 1195915       1195915    244476  12221127622105914440     12        0      52
#
#          UGEMEINDE  UJAHR  UMONAT  USTUNDE  ...  IstRad  IstPKW  IstFuss  \
# 59914           17   2018       1       14  ...       1       1        0
# 59915          160   2018       1       14  ...       1       1        0
# 59916          481   2018       1        6  ...       0       1        0
# 59917          428   2018       1       15  ...       1       0        0
# 59918           76   2018       1        6  ...       0       1        0
# ...            ...    ...     ...      ...  ...     ...     ...      ...
# 1195893          0   2022      12       16  ...       0       1        1
# 1195896        433   2022      12        2  ...       0       1        0
# 1195905          0   2022      12        9  ...       1       1        0
# 1195908          0   2022      12       13  ...       1       0        0
# 1195915          0   2022      11       14  ...       1       1        0
#
#          IstKrad  IstGkfz  IstSonstige                 LINREFX  \
# 59914          0        0            0  800009,585300000040000
# 59915          0        0            0  891847,242699999940000
# 59916          0        0            0  834011,048599999980000
# 59917          0        0            0  828916,610600000010000
# 59918          0        0            0  888674,614500000030000
# ...          ...      ...          ...                     ...
# 1195893        0        0            0  877986,113213442033157
# 1195896        0        0            0  807573,971324575017206
# 1195905        0        0            0  867068,079912201967090
# 1195908        0        0            0  741040,434166979975998
# 1195915        0        0            0  866685,130248917965218
#
#                          LINREFY  Longitude   Latitude
# 59914    5809193,854399999600000  13.405709  52.350773
# 59915    5770605,803700000000000  14.703484  51.947739
# 59916    5806798,498800000200000  13.900769  52.309679
# 59917    5826754,858300000400000  13.845904  52.491527
# 59918    5745921,514299999900000  14.629845  51.729098
# ...                          ...        ...        ...
# 1195893  5813572,529705960303545  14.550509  52.341827
# 1195896  5815031,160866759717464  13.521775  52.398901
# 1195905  5744877,056088720448315  14.317275  51.734299
# 1195908  5812444,582160020247102  12.544087  52.409038
# 1195915  5747581,105392109602690  14.314602  51.758758
#
# [102979 rows x 26 columns]

# %%
import geopandas as gpd
from shapely.geometry import Point
import matplotlib.pyplot as plt

# %%
berlin_brandenb_df['Point'] = berlin_brandenb_df.apply(lambda row: Point(row['Longitude'], row['Latitude']), axis=1)
accident_gdf = gpd.GeoDataFrame(berlin_brandenb_df, geometry='Point')
accident_gdf.set_crs(epsg=4326, inplace=True)
print(accident_gdf.crs)
accident_25833 = accident_gdf.to_crs('EPSG:25833')

fig, ax = plt.subplots(figsize=(10, 10))
accident_25833.plot(ax=ax, color='red', markersize=5)
plt.show()
# Out:
# C:\Users\Domen\AppData\Local\Temp\ipykernel_11868\1855456901.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   berlin_brandenb_df['Point'] = berlin_brandenb_df.apply(lambda row: Point(row['Longitude'], row['Latitude']), axis=1)
# EPSG:4326

# %%
accident_gdf
# Out:
#          NEW_OBJECTID  OBJECTID           UIDENTSTLAE  ULAND  UREGBEZ  UKREIS  \
# 59914           59914     59915                  None     12        0      72
# 59915           59915     59916                  None     12        0      71
# 59916           59916     59917                  None     12        0      67
# 59917           59917     59918                  None     12        0      64
# 59918           59918     59919                  None     12        0      71
# ...               ...       ...                   ...    ...      ...     ...
# 1195893       1195893    244454  12221223522702969070     12        0      53
# 1195896       1195896    244457  12221208662102936780     12        0      61
# 1195905       1195905    244466  12221220622203963240     12        0      52
# 1195908       1195908    244469  12221206722103933670     12        0      51
# 1195915       1195915    244476  12221127622105914440     12        0      52
#
#          UGEMEINDE  UJAHR  UMONAT  USTUNDE  ...  IstPKW  IstFuss  IstKrad  \
# 59914           17   2018       1       14  ...       1        0        0
# 59915          160   2018       1       14  ...       1        0        0
# 59916          481   2018       1        6  ...       1        0        0
# 59917          428   2018       1       15  ...       0        0        0
# 59918           76   2018       1        6  ...       1        0        0
# ...            ...    ...     ...      ...  ...     ...      ...      ...
# 1195893          0   2022      12       16  ...       1        1        0
# 1195896        433   2022      12        2  ...       1        0        0
# 1195905          0   2022      12        9  ...       1        0        0
# 1195908          0   2022      12       13  ...       0        0        0
# 1195915          0   2022      11       14  ...       1        0        0
#
#          IstGkfz  IstSonstige                 LINREFX  \
# 59914          0            0  800009,585300000040000
# 59915          0            0  891847,242699999940000
# 59916          0            0  834011,048599999980000
# 59917          0            0  828916,610600000010000
# 59918          0            0  888674,614500000030000
# ...          ...          ...                     ...
# 1195893        0            0  877986,113213442033157
# 1195896        0            0  807573,971324575017206
# 1195905        0            0  867068,079912201967090
# 1195908        0            0  741040,434166979975998
# 1195915        0            0  866685,130248917965218
#
#                          LINREFY  Longitude   Latitude  \
# 59914    5809193,854399999600000  13.405709  52.350773
# 59915    5770605,803700000000000  14.703484  51.947739
# 59916    5806798,498800000200000  13.900769  52.309679
# 59917    5826754,858300000400000  13.845904  52.491527
# 59918    5745921,514299999900000  14.629845  51.729098
# ...                          ...        ...        ...
# 1195893  5813572,529705960303545  14.550509  52.341827
# 1195896  5815031,160866759717464  13.521775  52.398901
# 1195905  5744877,056088720448315  14.317275  51.734299
# 1195908  5812444,582160020247102  12.544087  52.409038
# 1195915  5747581,105392109602690  14.314602  51.758758
#
#                              Point
# 59914    POINT (13.40571 52.35077)
# 59915    POINT (14.70348 51.94774)
# 59916    POINT (13.90077 52.30968)
# 59917    POINT (13.84590 52.49153)
# 59918    POINT (14.62985 51.72910)
# ...                            ...
# 1195893  POINT (14.55051 52.34183)
# 1195896  POINT (13.52177 52.39890)
# 1195905  POINT (14.31728 51.73430)
# 1195908  POINT (12.54409 52.40904)
# 1195915  POINT (14.31460 51.75876)
#
# [102979 rows x 27 columns]

# %% [markdown]
# ## Import LOR Gebiete

# %%
with open(f"../data/input/berlin/lor_planungsraeume_2021.geojson", 'r', encoding='utf-8') as f:
    LOR_gdf = gpd.read_file(f)
    

# print(LOR_gdf.crs)
# fig, ax = plt.subplots(figsize=(10, 10))
# LOR_gdf.plot(ax=ax, color='red', markersize=5)
# plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 10))
accident_25833.plot(ax=ax, color='red', markersize=5)
LOR_gdf.plot(ax=ax, color='blue', edgecolor='k')

plt.show()

# %%
berlin_lor = gpd.sjoin(accident_25833, LOR_gdf, how='left', op='intersects')
berlin_lor = berlin_lor.drop(columns=['index_right', 'PLR_NAME', 'BEZ', 'STAND', 'GROESSE_M2'])
# Out:
# C:\Users\Domen\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):

# %%
berlin_lor
# Out:
#          NEW_OBJECTID  OBJECTID           UIDENTSTLAE  ULAND  UREGBEZ  UKREIS  \
# 59914           59914     59915                  None     12        0      72
# 59915           59915     59916                  None     12        0      71
# 59916           59916     59917                  None     12        0      67
# 59917           59917     59918                  None     12        0      64
# 59918           59918     59919                  None     12        0      71
# ...               ...       ...                   ...    ...      ...     ...
# 1195893       1195893    244454  12221223522702969070     12        0      53
# 1195896       1195896    244457  12221208662102936780     12        0      61
# 1195905       1195905    244466  12221220622203963240     12        0      52
# 1195908       1195908    244469  12221206722103933670     12        0      51
# 1195915       1195915    244476  12221127622105914440     12        0      52
#
#          UGEMEINDE  UJAHR  UMONAT  USTUNDE  ...  IstFuss  IstKrad  IstGkfz  \
# 59914           17   2018       1       14  ...        0        0        0
# 59915          160   2018       1       14  ...        0        0        0
# 59916          481   2018       1        6  ...        0        0        0
# 59917          428   2018       1       15  ...        0        0        0
# 59918           76   2018       1        6  ...        0        0        0
# ...            ...    ...     ...      ...  ...      ...      ...      ...
# 1195893          0   2022      12       16  ...        1        0        0
# 1195896        433   2022      12        2  ...        0        0        0
# 1195905          0   2022      12        9  ...        0        0        0
# 1195908          0   2022      12       13  ...        0        0        0
# 1195915          0   2022      11       14  ...        0        0        0
#
#          IstSonstige                 LINREFX                  LINREFY  \
# 59914              0  800009,585300000040000  5809193,854399999600000
# 59915              0  891847,242699999940000  5770605,803700000000000
# 59916              0  834011,048599999980000  5806798,498800000200000
# 59917              0  828916,610600000010000  5826754,858300000400000
# 59918              0  888674,614500000030000  5745921,514299999900000
# ...              ...                     ...                      ...
# 1195893            0  877986,113213442033157  5813572,529705960303545
# 1195896            0  807573,971324575017206  5815031,160866759717464
# 1195905            0  867068,079912201967090  5744877,056088720448315
# 1195908            0  741040,434166979975998  5812444,582160020247102
# 1195915            0  866685,130248917965218  5747581,105392109602690
#
#          Longitude   Latitude                           Point  PLR_ID
# 59914    13.405709  52.350773  POINT (391412.128 5801249.660)     NaN
# 59915    14.703484  51.947739  POINT (479620.372 5755267.173)     NaN
# 59916    13.900769  52.309679  POINT (425060.190 5796051.386)     NaN
# 59917    13.845904  52.491527  POINT (421642.755 5816335.597)     NaN
# 59918    14.629845  51.729098  POINT (474435.622 5730973.247)     NaN
# ...            ...        ...                             ...     ...
# 1195893  14.550509  52.341827  POINT (469377.882 5799153.331)     NaN
# 1195896  13.521775  52.398901  POINT (399426.351 5806434.655)     NaN
# 1195905  14.317275  51.734299  POINT (452853.868 5731707.388)     NaN
# 1195908  12.544087  52.409038  POINT (332954.257 5809371.714)     NaN
# 1195915  14.314602  51.758758  POINT (452694.807 5734429.343)     NaN
#
# [102979 rows x 28 columns]

# %% [markdown]
# ## Import Ortsteile

# %%
with open(f"../data/input/berlin/lor_ortsteile.geojson", 'r', encoding='utf-8') as f:
    ortsteile_gdf = gpd.read_file(f)

# %%
print(ortsteile_gdf.crs)
ortsteile_25833 = ortsteile_gdf.to_crs('EPSG:25833')
print(ortsteile_25833.crs)


fig, ax = plt.subplots(figsize=(10, 10))
ortsteile_25833.plot(ax=ax, color='red', markersize=5)

plt.show()
# Out:
# EPSG:4326
# EPSG:25833

# %%
berlin_lor = gpd.sjoin(berlin_lor, ortsteile_25833, how='left', op='intersects')
berlin_lor = berlin_lor.drop(columns=['index_right',
       'spatial_name', 'spatial_alias', 'spatial_type', 'OTEIL', 'BEZIRK',
       'FLAECHE_HA'])
# Out:
# C:\Users\Domen\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):

# %%
berlin_lor.head(1)
# Out:
#        NEW_OBJECTID  OBJECTID UIDENTSTLAE  ULAND  UREGBEZ  UKREIS  UGEMEINDE  \
# 59914         59914     59915        None     12        0      72         17
#
#        UJAHR  UMONAT  USTUNDE  ...  IstKrad  IstGkfz  IstSonstige  \
# 59914   2018       1       14  ...        0        0            0
#
#                       LINREFX                  LINREFY  Longitude   Latitude  \
# 59914  800009,585300000040000  5809193,854399999600000  13.405709  52.350773
#
#                                 Point  PLR_ID  gml_id
# 59914  POINT (391412.128 5801249.660)     NaN     NaN
#
# [1 rows x 29 columns]

# %%
berlin_lor.columns
# Out:
# Index(['NEW_OBJECTID', 'OBJECTID', 'UIDENTSTLAE', 'ULAND', 'UREGBEZ', 'UKREIS',
#        'UGEMEINDE', 'UJAHR', 'UMONAT', 'USTUNDE', 'UWOCHENTAG', 'UKATEGORIE',
#        'UART', 'UTYP1', 'ULICHTVERH', 'STRZUSTAND', 'IstRad', 'IstPKW',
#        'IstFuss', 'IstKrad', 'IstGkfz', 'IstSonstige', 'LINREFX', 'LINREFY',
#        'Longitude', 'Latitude', 'Point', 'PLR_ID', 'gml_id'],
#       dtype='object')

# %%
with open(f"../data/input/berlin/Detailnetz-Strassenabschnitte.geojson", 'r', encoding='utf-8') as f:
    strassenabschnitte = gpd.read_file(f)

print(strassenabschnitte.crs)

strassen_25833 = strassenabschnitte.to_crs('EPSG:25833')

strassen_25833
# Out:
# EPSG:4326
#                  element_nr strassensc           strassenna str_bez  \
# 0      34610003_34610004.01      00002         Aalemannufer     NaN
# 1      40540001_41540003.01      00005           Abbestraße     NaN
# 2      42590002_42590001.01      00022  Afrikanische Straße     NaN
# 3      42590003_42590004.01      00022  Afrikanische Straße     NaN
# 4      42590005_42590006.01      00022  Afrikanische Straße     NaN
# ...                     ...        ...                  ...     ...
# 43105  53530049_53530051.01      41423         Irenenstraße     NaN
# 43106  53530051_53530040.01      42456   Rosenfelder Straße     NaN
# 43107  53530061_53530040.01      40696     Einbecker Straße     NaN
# 43108  53530057_53530061.01      40696     Einbecker Straße     NaN
# 43109  53530037_53530057.01      40696     Einbecker Straße     NaN
#
#       strassenkl strassen_1 strassen_2 verkehrsri                      bezirk  \
# 0             IV          G       STRA          B                     Spandau
# 1              V          G       STRA          B  Charlottenburg-Wilmersdorf
# 2             II          G       STRA          B                       Mitte
# 3             II          G       STRA          B                       Mitte
# 4             II          G       STRA          B                       Mitte
# ...          ...        ...        ...        ...                         ...
# 43105          V          G       STRA          B                 Lichtenberg
# 43106          V          G       STRA          B                 Lichtenberg
# 43107        III          G       STRA          B                 Lichtenberg
# 43108        III          G       STRA          B                 Lichtenberg
# 43109        III          G       STRA          B                 Lichtenberg
#
#             stadtteil  verkehrseb beginnt_be endet_bei_    laenge gueltig_vo  \
# 0          Hakenfelde           0   34610003   34610004  262.5000 2010-01-01
# 1      Charlottenburg           0   40540001   41540003  182.4500 2010-01-01
# 2             Wedding           0   42590002   42590001   65.3600 2010-01-01
# 3             Wedding           0   42590003   42590004   61.4100 2010-01-01
# 4             Wedding           0   42590005   42590006   45.3600 2010-01-01
# ...               ...         ...        ...        ...       ...        ...
# 43105     Rummelsburg           0   53530049   53530051  192.8000 2021-03-04
# 43106     Rummelsburg           0   53530051   53530040  123.1700 2021-03-04
# 43107     Rummelsburg           0   53530061   53530040  159.5962 2021-03-04
# 43108     Rummelsburg           0   53530057   53530061   52.6011 2021-03-04
# 43109     Rummelsburg           0   53530037   53530057   26.5570 2021-03-04
#
#                               okstra_id  \
# 0      D62521E5E27544729878420C54E6C59C
# 1      275EE05309AF45DCA49E046BBA0CBBCC
# 2      18F55F73EB5346F6A7A719E970B9D4EC
# 3      AE661AB3DB344DD183550F05E15A4BD7
# 4      D47D9FE02F13481FA79966646BA478FA
# ...                                 ...
# 43105  BBA9B5EF7DB242898DDE1E53868D9227
# 43106  92AD8579703C4E12B378108ED328B192
# 43107  D8CB50FB08E34C0A8AA1A0095A40B0EF
# 43108  2EB39A91A5AB43B3B612EC86DE4A3DD6
# 43109  B459974AF75D425DAF7DC37C64D64175
#
#                                                 geometry
# 0      MULTILINESTRING ((379370.746 5826268.611, 3795...
# 1      MULTILINESTRING ((385991.039 5819676.776, 3860...
# 2      MULTILINESTRING ((387029.710 5824737.448, 3870...
# 3      MULTILINESTRING ((387078.894 5824336.242, 3870...
# 4      MULTILINESTRING ((387110.539 5824230.756, 3871...
# ...                                                  ...
# 43105  MULTILINESTRING ((398183.159 5818751.676, 3982...
# 43106  MULTILINESTRING ((398367.785 5818696.292, 3983...
# 43107  MULTILINESTRING ((398298.284 5818856.922, 3984...
# 43108  MULTILINESTRING ((398252.357 5818882.558, 3982...
# 43109  MULTILINESTRING ((398232.451 5818899.492, 3982...
#
# [43110 rows x 17 columns]

# %% [markdown]
# ## Import Strassenabschnitte

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10, 10))
strassen_25833.plot(ax=ax, color='blue', edgecolor='k')
berlin_lor.plot(ax=ax, color='red', markersize=5)
plt.show()

# %%
nearest_line = gpd.sjoin_nearest(berlin_lor, strassen_25833, distance_col='distance')
nearest_line.T
# Out:
#                                                    59914    \
# NEW_OBJECTID                                         59914
# OBJECTID                                             59915
# UIDENTSTLAE                                           None
# ULAND                                                   12
# UREGBEZ                                                  0
# UKREIS                                                  72
# UGEMEINDE                                               17
# UJAHR                                                 2018
# UMONAT                                                   1
# USTUNDE                                                 14
# UWOCHENTAG                                               5
# UKATEGORIE                                               3
# UART                                                     5
# UTYP1                                                    3
# ULICHTVERH                                               0
# STRZUSTAND                                               1
# IstRad                                                   1
# IstPKW                                                   1
# IstFuss                                                  0
# IstKrad                                                  0
# IstGkfz                                                  0
# IstSonstige                                              0
# LINREFX                             800009,585300000040000
# LINREFY                            5809193,854399999600000
# Longitude                                        13.405709
# Latitude                                         52.350773
# Point         POINT (391412.12849155953 5801249.659980662)
# PLR_ID                                                 NaN
# gml_id                                                 NaN
# index_right                                          16234
# element_nr                            46390046_46390050.02
# strassensc                                           04159
# strassenna                                  Seydlitzstraße
# str_bez                                                NaN
# strassenkl                                               V
# strassen_1                                               G
# strassen_2                                            STRA
# verkehrsri                                               B
# bezirk                                Tempelhof-Schöneberg
# stadtteil                                      Lichtenrade
# verkehrseb                                               0
# beginnt_be                                        46390046
# endet_bei_                                        46390050
# laenge                                               48.66
# gueltig_vo                             2014-09-16 00:00:00
# okstra_id                 B0BA1D4FB553446AB4123C3953A5FBB6
# distance                                       2900.757961
#
#                                                   61617    \
# NEW_OBJECTID                                        61617
# OBJECTID                                            61618
# UIDENTSTLAE                                          None
# ULAND                                                  12
# UREGBEZ                                                 0
# UKREIS                                                 72
# UGEMEINDE                                              17
# UJAHR                                                2018
# UMONAT                                                  4
# USTUNDE                                                21
# UWOCHENTAG                                              1
# UKATEGORIE                                              3
# UART                                                    2
# UTYP1                                                   6
# ULICHTVERH                                              2
# STRZUSTAND                                              0
# IstRad                                                  0
# IstPKW                                                  1
# IstFuss                                                 0
# IstKrad                                                 1
# IstGkfz                                                 0
# IstSonstige                                             0
# LINREFX                            800350,154199999990000
# LINREFY                           5811043,602800000500000
# Longitude                                       13.412349
# Latitude                                        52.367167
# Point         POINT (391904.3495615534 5803063.075382012)
# PLR_ID                                                NaN
# gml_id                                                NaN
# index_right                                         16234
# element_nr                           46390046_46390050.02
# strassensc                                          04159
# strassenna                                 Seydlitzstraße
# str_bez                                               NaN
# strassenkl                                              V
# strassen_1                                              G
# strassen_2                                           STRA
# verkehrsri                                              B
# bezirk                               Tempelhof-Schöneberg
# stadtteil                                     Lichtenrade
# verkehrseb                                              0
# beginnt_be                                       46390046
# endet_bei_                                       46390050
# laenge                                              48.66
# gueltig_vo                            2014-09-16 00:00:00
# okstra_id                B0BA1D4FB553446AB4123C3953A5FBB6
# distance                                      1066.457522
#
#                                                    61720    \
# NEW_OBJECTID                                         61720
# OBJECTID                                             61721
# UIDENTSTLAE                                           None
# ULAND                                                   12
# UREGBEZ                                                  0
# UKREIS                                                  72
# UGEMEINDE                                               17
# UJAHR                                                 2018
# UMONAT                                                   6
# USTUNDE                                                 19
# UWOCHENTAG                                               7
# UKATEGORIE                                               3
# UART                                                     7
# UTYP1                                                    4
# ULICHTVERH                                               0
# STRZUSTAND                                               0
# IstRad                                                   0
# IstPKW                                                   1
# IstFuss                                                  1
# IstKrad                                                  0
# IstGkfz                                                  0
# IstSonstige                                              0
# LINREFX                             800364,173300000020000
# LINREFY                            5810821,521700000400000
# Longitude                                        13.412355
# Latitude                                         52.365169
# Point         POINT (391899.91801746277 5802840.810715396)
# PLR_ID                                                 NaN
# gml_id                                                 NaN
# index_right                                          16234
# element_nr                            46390046_46390050.02
# strassensc                                           04159
# strassenna                                  Seydlitzstraße
# str_bez                                                NaN
# strassenkl                                               V
# strassen_1                                               G
# strassen_2                                            STRA
# verkehrsri                                               B
# bezirk                                Tempelhof-Schöneberg
# stadtteil                                      Lichtenrade
# verkehrseb                                               0
# beginnt_be                                        46390046
# endet_bei_                                        46390050
# laenge                                               48.66
# gueltig_vo                             2014-09-16 00:00:00
# okstra_id                 B0BA1D4FB553446AB4123C3953A5FBB6
# distance                                       1287.483729
#
#                                                  61784    \
# NEW_OBJECTID                                       61784
# OBJECTID                                           61785
# UIDENTSTLAE                                         None
# ULAND                                                 12
# UREGBEZ                                                0
# UKREIS                                                72
# UGEMEINDE                                             17
# UJAHR                                               2018
# UMONAT                                                 5
# USTUNDE                                               11
# UWOCHENTAG                                             4
# UKATEGORIE                                             3
# UART                                                   2
# UTYP1                                                  6
# ULICHTVERH                                             0
# STRZUSTAND                                             0
# IstRad                                                 0
# IstPKW                                                 1
# IstFuss                                                0
# IstKrad                                                0
# IstGkfz                                                0
# IstSonstige                                            0
# LINREFX                           800164,719200000050000
# LINREFY                          5809958,096900000200000
# Longitude                                      13.408663
# Latitude                                       52.357539
# Point         POINT (391629.851759654 5801997.698790133)
# PLR_ID                                               NaN
# gml_id                                               NaN
# index_right                                        16234
# element_nr                          46390046_46390050.02
# strassensc                                         04159
# strassenna                                Seydlitzstraße
# str_bez                                              NaN
# strassenkl                                             V
# strassen_1                                             G
# strassen_2                                          STRA
# verkehrsri                                             B
# bezirk                              Tempelhof-Schöneberg
# stadtteil                                    Lichtenrade
# verkehrseb                                             0
# beginnt_be                                      46390046
# endet_bei_                                      46390050
# laenge                                             48.66
# gueltig_vo                           2014-09-16 00:00:00
# okstra_id               B0BA1D4FB553446AB4123C3953A5FBB6
# distance                                     2133.476843
#
#                                                   62219    \
# NEW_OBJECTID                                        62219
# OBJECTID                                            62220
# UIDENTSTLAE                                          None
# ULAND                                                  12
# UREGBEZ                                                 0
# UKREIS                                                 72
# UGEMEINDE                                              17
# UJAHR                                                2018
# UMONAT                                                  5
# USTUNDE                                                16
# UWOCHENTAG                                              3
# UKATEGORIE                                              3
# UART                                                    2
# UTYP1                                                   6
# ULICHTVERH                                              0
# STRZUSTAND                                              0
# IstRad                                                  0
# IstPKW                                                  1
# IstFuss                                                 0
# IstKrad                                                 0
# IstGkfz                                                 0
# IstSonstige                                             0
# LINREFX                            799976,104500000020000
# LINREFY                           5806920,706000000200000
# Longitude                                       13.403191
# Latitude                                        52.330415
# Point         POINT (391190.6355133832 5798989.271582791)
# PLR_ID                                                NaN
# gml_id                                                NaN
# index_right                                         16234
# element_nr                           46390046_46390050.02
# strassensc                                          04159
# strassenna                                 Seydlitzstraße
# str_bez                                               NaN
# strassenkl                                              V
# strassen_1                                              G
# strassen_2                                           STRA
# verkehrsri                                              B
# bezirk                               Tempelhof-Schöneberg
# stadtteil                                     Lichtenrade
# verkehrseb                                              0
# beginnt_be                                       46390046
# endet_bei_                                       46390050
# laenge                                              48.66
# gueltig_vo                            2014-09-16 00:00:00
# okstra_id                B0BA1D4FB553446AB4123C3953A5FBB6
# distance                                      5171.129917
#
#                                                   62239    \
# NEW_OBJECTID                                        62239
# OBJECTID                                            62240
# UIDENTSTLAE                                          None
# ULAND                                                  12
# UREGBEZ                                                 0
# UKREIS                                                 72
# UGEMEINDE                                              17
# UJAHR                                                2018
# UMONAT                                                  6
# USTUNDE                                                15
# UWOCHENTAG                                              6
# UKATEGORIE                                              3
# UART                                                    5
# UTYP1                                                   7
# ULICHTVERH                                              0
# STRZUSTAND                                              0
# IstRad                                                  1
# IstPKW                                                  1
# IstFuss                                                 0
# IstKrad                                                 0
# IstGkfz                                                 0
# IstSonstige                                             0
# LINREFX                            799989,118999999950000
# LINREFY                           5806918,514000000400000
# Longitude                                       13.403379
# Latitude                                        52.330388
# Point         POINT (391203.4114102041 5798986.012040241)
# PLR_ID                                                NaN
# gml_id                                                NaN
# index_right                                         16234
# element_nr                           46390046_46390050.02
# strassensc                                          04159
# strassenna                                 Seydlitzstraße
# str_bez                                               NaN
# strassenkl                                              V
# strassen_1                                              G
# strassen_2                                           STRA
# verkehrsri                                              B
# bezirk                               Tempelhof-Schöneberg
# stadtteil                                     Lichtenrade
# verkehrseb                                              0
# beginnt_be                                       46390046
# endet_bei_                                       46390050
# laenge                                              48.66
# gueltig_vo                            2014-09-16 00:00:00
# okstra_id                B0BA1D4FB553446AB4123C3953A5FBB6
# distance                                      5172.878262
#
#                                                    62989    \
# NEW_OBJECTID                                         62989
# OBJECTID                                             62990
# UIDENTSTLAE                                           None
# ULAND                                                   12
# UREGBEZ                                                  0
# UKREIS                                                  72
# UGEMEINDE                                               17
# UJAHR                                                 2018
# UMONAT                                                   8
# USTUNDE                                                  7
# UWOCHENTAG                                               5
# UKATEGORIE                                               3
# UART                                                     5
# UTYP1                                                    3
# ULICHTVERH                                               0
# STRZUSTAND                                               0
# IstRad                                                   1
# IstPKW                                                   1
# IstFuss                                                  0
# IstKrad                                                  0
# IstGkfz                                                  0
# IstSonstige                                              0
# LINREFX                             800296,275000000020000
# LINREFY                            5810305,660199999800000
# Longitude                                          13.4109
# Latitude                                         52.360582
# Point         POINT (391789.60550653643 5802332.841115155)
# PLR_ID                                                 NaN
# gml_id                                                 NaN
# index_right                                          16234
# element_nr                            46390046_46390050.02
# strassensc                                           04159
# strassenna                                  Seydlitzstraße
# str_bez                                                NaN
# strassenkl                                               V
# strassen_1                                               G
# strassen_2                                            STRA
# verkehrsri                                               B
# bezirk                                Tempelhof-Schöneberg
# stadtteil                                      Lichtenrade
# verkehrseb                                               0
# beginnt_be                                        46390046
# endet_bei_                                        46390050
# laenge                                               48.66
# gueltig_vo                             2014-09-16 00:00:00
# okstra_id                 B0BA1D4FB553446AB4123C3953A5FBB6
# distance                                       1791.583809
#
#                                                    63108    \
# NEW_OBJECTID                                         63108
# OBJECTID                                             63109
# UIDENTSTLAE                                           None
# ULAND                                                   12
# UREGBEZ                                                  0
# UKREIS                                                  72
# UGEMEINDE                                               17
# UJAHR                                                 2018
# UMONAT                                                   7
# USTUNDE                                                 18
# UWOCHENTAG                                               3
# UKATEGORIE                                               3
# UART                                                     5
# UTYP1                                                    3
# ULICHTVERH                                               0
# STRZUSTAND                                               0
# IstRad                                                   1
# IstPKW                                                   1
# IstFuss                                                  0
# IstKrad                                                  0
# IstGkfz                                                  0
# IstSonstige                                              0
# LINREFX                             800254,381799999970000
# LINREFY                            5810014,652499999900000
# Longitude                                        13.410026
# Latitude                                         52.357997
# Point         POINT (391723.80248684075 5802046.582173319)
# PLR_ID                                                 NaN
# gml_id                                                 NaN
# index_right                                          16234
# element_nr                            46390046_46390050.02
# strassensc                                           04159
# strassenna                                  Seydlitzstraße
# str_bez                                                NaN
# strassenkl                                               V
# strassen_1                                               G
# strassen_2                                            STRA
# verkehrsri                                               B
# bezirk                                Tempelhof-Schöneberg
# stadtteil                                      Lichtenrade
# verkehrseb                                               0
# beginnt_be                                        46390046
# endet_bei_                                        46390050
# laenge                                               48.66
# gueltig_vo                             2014-09-16 00:00:00
# okstra_id                 B0BA1D4FB553446AB4123C3953A5FBB6
# distance                                       2079.203148
#
#                                                   63580    \
# NEW_OBJECTID                                        63580
# OBJECTID                                            63581
# UIDENTSTLAE                                          None
# ULAND                                                  12
# UREGBEZ                                                 0
# UKREIS                                                 72
# UGEMEINDE                                              17
# UJAHR                                                2018
# UMONAT                                                  7
# USTUNDE                                                10
# UWOCHENTAG                                              6
# UKATEGORIE                                              3
# UART                                                    5
# UTYP1                                                   3
# ULICHTVERH                                              0
# STRZUSTAND                                              0
# IstRad                                                  0
# IstPKW                                                  1
# IstFuss                                                 0
# IstKrad                                                 1
# IstGkfz                                                 0
# IstSonstige                                             0
# LINREFX                            800008,407800000040000
# LINREFY                           5806915,861600000400000
# Longitude                                       13.403659
# Latitude                                        52.330354
# Point         POINT (391222.3959978515 5798981.774905238)
# PLR_ID                                                NaN
# gml_id                                                NaN
# index_right                                         16234
# element_nr                           46390046_46390050.02
# strassensc                                          04159
# strassenna                                 Seydlitzstraße
# str_bez                                               NaN
# strassenkl                                              V
# strassen_1                                              G
# strassen_2                                           STRA
# verkehrsri                                              B
# bezirk                               Tempelhof-Schöneberg
# stadtteil                                     Lichtenrade
# verkehrseb                                              0
# beginnt_be                                       46390046
# endet_bei_                                       46390050
# laenge                                              48.66
# gueltig_vo                            2014-09-16 00:00:00
# okstra_id                B0BA1D4FB553446AB4123C3953A5FBB6
# distance                                      5174.934541
#
#                                                   64136    ...  \
# NEW_OBJECTID                                        64136  ...
# OBJECTID                                            64137  ...
# UIDENTSTLAE                                          None  ...
# ULAND                                                  12  ...
# UREGBEZ                                                 0  ...
# UKREIS                                                 72  ...
# UGEMEINDE                                              17  ...
# UJAHR                                                2018  ...
# UMONAT                                                  8  ...
# USTUNDE                                                13  ...
# UWOCHENTAG                                              6  ...
# UKATEGORIE                                              2  ...
# UART                                                    2  ...
# UTYP1                                                   6  ...
# ULICHTVERH                                              0  ...
# STRZUSTAND                                              0  ...
# IstRad                                                  0  ...
# IstPKW                                                  1  ...
# IstFuss                                                 0  ...
# IstKrad                                                 0  ...
# IstGkfz                                                 0  ...
# IstSonstige                                             0  ...
# LINREFX                            799948,371799999960000  ...
# LINREFY                           5804226,053600000200000  ...
# Longitude                                       13.400384  ...
# Latitude                                        52.306276  ...
# Point         POINT (390940.0419592637 5796308.746992239)  ...
# PLR_ID                                                NaN  ...
# gml_id                                                NaN  ...
# index_right                                         16234  ...
# element_nr                           46390046_46390050.02  ...
# strassensc                                          04159  ...
# strassenna                                 Seydlitzstraße  ...
# str_bez                                               NaN  ...
# strassenkl                                              V  ...
# strassen_1                                              G  ...
# strassen_2                                           STRA  ...
# verkehrsri                                              B  ...
# bezirk                               Tempelhof-Schöneberg  ...
# stadtteil                                     Lichtenrade  ...
# verkehrseb                                              0  ...
# beginnt_be                                       46390046  ...
# endet_bei_                                       46390050  ...
# laenge                                              48.66  ...
# gueltig_vo                            2014-09-16 00:00:00  ...
# okstra_id                B0BA1D4FB553446AB4123C3953A5FBB6  ...
# distance                                       7862.79555  ...
#
#                                                  1192307  \
# NEW_OBJECTID                                     1192307
# OBJECTID                                          240868
# UIDENTSTLAE                         11221211110000035550
# ULAND                                                 11
# UREGBEZ                                                0
# UKREIS                                                 6
# UGEMEINDE                                              6
# UJAHR                                               2022
# UMONAT                                                12
# USTUNDE                                               17
# UWOCHENTAG                                             1
# UKATEGORIE                                             2
# UART                                                   9
# UTYP1                                                  1
# ULICHTVERH                                             2
# STRZUSTAND                                             0
# IstRad                                                 0
# IstPKW                                                 1
# IstFuss                                                0
# IstKrad                                                0
# IstGkfz                                                0
# IstSonstige                                            0
# LINREFX                           794111,819997426006012
# LINREFY                          5815232,134797899983823
# Longitude                                      13.324664
# Latitude                                       52.408098
# Point         POINT (386040.2182826493 5807750.00506276)
# PLR_ID                                          06200423
# gml_id                                  re_ortsteil.0602
# index_right                                         2776
# element_nr                          40430022_41420007.01
# strassensc                                         03341
# strassenna                               Osdorfer Straße
# str_bez                                              NaN
# strassenkl                                           III
# strassen_1                                             G
# strassen_2                                          STRA
# verkehrsri                                             B
# bezirk                               Steglitz-Zehlendorf
# stadtteil                                   Lichterfelde
# verkehrseb                                             0
# beginnt_be                                      40430022
# endet_bei_                                      41420007
# laenge                                            308.98
# gueltig_vo                           2010-01-01 00:00:00
# okstra_id               1E989E8FF0DE47C7920669377CF7C935
# distance                                        0.033283
#
#                                                   1192317  \
# NEW_OBJECTID                                      1192317
# OBJECTID                                           240878
# UIDENTSTLAE                          11221230110000085240
# ULAND                                                  11
# UREGBEZ                                                 0
# UKREIS                                                  4
# UGEMEINDE                                               4
# UJAHR                                                2022
# UMONAT                                                 12
# USTUNDE                                                13
# UWOCHENTAG                                              6
# UKATEGORIE                                              3
# UART                                                    6
# UTYP1                                                   4
# ULICHTVERH                                              0
# STRZUSTAND                                              0
# IstRad                                                  1
# IstPKW                                                  0
# IstFuss                                                 1
# IstKrad                                                 0
# IstGkfz                                                 0
# IstSonstige                                             0
# LINREFX                            794369,785997104016133
# LINREFY                           5825450,564795419573784
# Longitude                                       13.337453
# Latitude                                        52.499563
# Point         POINT (387144.2002533056 5817902.599548747)
# PLR_ID                                           04501045
# gml_id                                   re_ortsteil.0402
# index_right                                         20917
# element_nr                           42520016_42530043.03
# strassensc                                          04961
# strassenna                              Würzburger Straße
# str_bez                                               NaN
# strassenkl                                              V
# strassen_1                                              G
# strassen_2                                           STRA
# verkehrsri                                              B
# bezirk                         Charlottenburg-Wilmersdorf
# stadtteil                                     Wilmersdorf
# verkehrseb                                              0
# beginnt_be                                       42520016
# endet_bei_                                       42530043
# laenge                                             101.87
# gueltig_vo                            2014-09-16 00:00:00
# okstra_id                5604A12E78C9429FB413481E2554D63C
# distance                                         8.303254
#
#                                                   1192347  \
# NEW_OBJECTID                                      1192347
# OBJECTID                                           240908
# UIDENTSTLAE                          11221216110000055010
# ULAND                                                  11
# UREGBEZ                                                 0
# UKREIS                                                  7
# UGEMEINDE                                               7
# UJAHR                                                2022
# UMONAT                                                 12
# USTUNDE                                                21
# UWOCHENTAG                                              6
# UKATEGORIE                                              3
# UART                                                    1
# UTYP1                                                   5
# ULICHTVERH                                              2
# STRZUSTAND                                              1
# IstRad                                                  1
# IstPKW                                                  1
# IstFuss                                                 0
# IstKrad                                                 0
# IstGkfz                                                 0
# IstSonstige                                             0
# LINREFX                            795108,988904246012680
# LINREFY                           5825297,404789079912007
# Longitude                                       13.348176
# Latitude                                        52.497791
# Point         POINT (387867.4751030473 5817688.788741222)
# PLR_ID                                           07100102
# gml_id                                   re_ortsteil.0701
# index_right                                         20875
# element_nr                           42520051_42520057.02
# strassensc                                          03133
# strassenna                                     Motzstraße
# str_bez                                               NaN
# strassenkl                                              V
# strassen_1                                              G
# strassen_2                                           STRA
# verkehrsri                                              B
# bezirk                               Tempelhof-Schöneberg
# stadtteil                                      Schöneberg
# verkehrseb                                              0
# beginnt_be                                       42520051
# endet_bei_                                       42520057
# laenge                                              31.24
# gueltig_vo                            2014-09-16 00:00:00
# okstra_id                098DB65843EE4854B71042CAF601929B
# distance                                         0.357513
#
#                                                    1192364  \
# NEW_OBJECTID                                       1192364
# OBJECTID                                            240925
# UIDENTSTLAE                           11221211110000035690
# ULAND                                                   11
# UREGBEZ                                                  0
# UKREIS                                                   2
# UGEMEINDE                                                2
# UJAHR                                                 2022
# UMONAT                                                  12
# USTUNDE                                                 19
# UWOCHENTAG                                               1
# UKATEGORIE                                               3
# UART                                                     0
# UTYP1                                                    4
# ULICHTVERH                                               2
# STRZUSTAND                                               0
# IstRad                                                   0
# IstPKW                                                   1
# IstFuss                                                  1
# IstKrad                                                  1
# IstGkfz                                                  0
# IstSonstige                                              0
# LINREFX                             802872,233382713980973
# LINREFY                            5827260,776961119845510
# Longitude                                        13.463974
# Latitude                                         52.511136
# Point         POINT (395759.41100357333 5818999.500781142)
# PLR_ID                                            02500831
# gml_id                                    re_ortsteil.0201
# index_right                                          21114
# element_nr                            50540016_50530040.02
# strassensc                                           43540
# strassenna                                     Weserstraße
# str_bez                                                NaN
# strassenkl                                               V
# strassen_1                                               G
# strassen_2                                            STRA
# verkehrsri                                               B
# bezirk                            Friedrichshain-Kreuzberg
# stadtteil                                   Friedrichshain
# verkehrseb                                               0
# beginnt_be                                        50540016
# endet_bei_                                        50530040
# laenge                                               75.98
# gueltig_vo                             2014-09-16 00:00:00
# okstra_id                 28B9526C492F4FD0AF54EB226BFB4512
# distance                                          0.654043
#
#                                                    1192384  \
# NEW_OBJECTID                                       1192384
# OBJECTID                                            240945
# UIDENTSTLAE                           11221204110000001840
# ULAND                                                   11
# UREGBEZ                                                  0
# UKREIS                                                  10
# UGEMEINDE                                               10
# UJAHR                                                 2022
# UMONAT                                                  12
# USTUNDE                                                 13
# UWOCHENTAG                                               1
# UKATEGORIE                                               3
# UART                                                     1
# UTYP1                                                    5
# ULICHTVERH                                               0
# STRZUSTAND                                               1
# IstRad                                                   1
# IstPKW                                                   1
# IstFuss                                                  0
# IstKrad                                                  0
# IstGkfz                                                  0
# IstSonstige                                              0
# LINREFX                             811285,425559094990604
# LINREFY                            5827736,249232850037515
# Longitude                                        13.587993
# Latitude                                         52.510661
# Point         POINT (404174.31715962756 5818774.876969792)
# PLR_ID                                            10400836
# gml_id                                    re_ortsteil.1003
# index_right                                           8246
# element_nr                            59530049_59530015.01
# strassensc                                           42265
# strassenna                                   Planitzstraße
# str_bez                                                NaN
# strassenkl                                              IV
# strassen_1                                               G
# strassen_2                                            STRA
# verkehrsri                                               B
# bezirk                                 Marzahn-Hellersdorf
# stadtteil                                        Kaulsdorf
# verkehrseb                                               0
# beginnt_be                                        59530049
# endet_bei_                                        59530015
# laenge                                              121.49
# gueltig_vo                             2011-08-22 00:00:00
# okstra_id                 B323335ABB8245E6B673E24A3CCFBFCF
# distance                                          0.055987
#
#                                                    1192399  \
# NEW_OBJECTID                                       1192399
# OBJECTID                                            240960
# UIDENTSTLAE                           11221205110000003490
# ULAND                                                   11
# UREGBEZ                                                  0
# UKREIS                                                   9
# UGEMEINDE                                                9
# UJAHR                                                 2022
# UMONAT                                                  12
# USTUNDE                                                 12
# UWOCHENTAG                                               2
# UKATEGORIE                                               3
# UART                                                     5
# UTYP1                                                    3
# ULICHTVERH                                               0
# STRZUSTAND                                               1
# IstRad                                                   1
# IstPKW                                                   0
# IstFuss                                                  0
# IstKrad                                                  0
# IstGkfz                                                  0
# IstSonstige                                              0
# LINREFX                             809343,908464691019617
# LINREFY                            5819391,039504010230303
# Longitude                                        13.551736
# Latitude                                         52.436978
# Point         POINT (401549.5917912016 5810628.3152320925)
# PLR_ID                                            09200717
# gml_id                                    re_ortsteil.0907
# index_right                                          38827
# element_nr                            56450014_56450042.02
# strassensc                                           44817
# strassenna                                   Radickestraße
# str_bez                                                NaN
# strassenkl                                               V
# strassen_1                                               G
# strassen_2                                            STRA
# verkehrsri                                               B
# bezirk                                    Treptow-Köpenick
# stadtteil                                        Adlershof
# verkehrseb                                               0
# beginnt_be                                        56450014
# endet_bei_                                        56450042
# laenge                                              112.61
# gueltig_vo                             2016-11-11 00:00:00
# okstra_id                 47E73B0EDC5E43F2A9A0B7331E42605E
# distance                                           0.79723
#
#                                                    1192409  \
# NEW_OBJECTID                                       1192409
# OBJECTID                                            240970
# UIDENTSTLAE                           11221221110000070490
# ULAND                                                   11
# UREGBEZ                                                  0
# UKREIS                                                   9
# UGEMEINDE                                                9
# UJAHR                                                 2022
# UMONAT                                                  12
# USTUNDE                                                  1
# UWOCHENTAG                                               4
# UKATEGORIE                                               3
# UART                                                     8
# UTYP1                                                    1
# ULICHTVERH                                               2
# STRZUSTAND                                               1
# IstRad                                                   0
# IstPKW                                                   1
# IstFuss                                                  0
# IstKrad                                                  0
# IstGkfz                                                  0
# IstSonstige                                              0
# LINREFX                             809561,533233260037377
# LINREFY                            5815852,167966020293534
# Longitude                                        13.551654
# Latitude                                         52.405139
# Point         POINT (401473.0063577654 5807087.3299869085)
# PLR_ID                                            09300921
# gml_id                                    re_ortsteil.0906
# index_right                                          38075
# element_nr                            56420027_56420039.02
# strassensc                                           40386
# strassenna                                 Bohnsdorfer Weg
# str_bez                                                NaN
# strassenkl                                              IV
# strassen_1                                               G
# strassen_2                                            STRA
# verkehrsri                                               B
# bezirk                                    Treptow-Köpenick
# stadtteil                                     Altglienicke
# verkehrseb                                               0
# beginnt_be                                        56420027
# endet_bei_                                        56420039
# laenge                                               70.13
# gueltig_vo                             2016-07-26 00:00:00
# okstra_id                 91AC0738AB5140F1A5EAE93C2B38BFC0
# distance                                          0.496318
#
#                                                    1192490  \
# NEW_OBJECTID                                       1192490
# OBJECTID                                            241051
# UIDENTSTLAE                           12220518742142519960
# ULAND                                                   12
# UREGBEZ                                                  0
# UKREIS                                                  63
# UGEMEINDE                                               56
# UJAHR                                                 2022
# UMONAT                                                   5
# USTUNDE                                                 10
# UWOCHENTAG                                               4
# UKATEGORIE                                               3
# UART                                                     5
# UTYP1                                                    3
# ULICHTVERH                                               0
# STRZUSTAND                                               0
# IstRad                                                   1
# IstPKW                                                   0
# IstFuss                                                  0
# IstKrad                                                  0
# IstGkfz                                                  1
# IstSonstige                                              0
# LINREFX                             780311,331294378964230
# LINREFY                            5825745,262098999693990
# Longitude                                        13.131154
# Latitude                                          52.50961
# Point         POINT (373170.46323842136 5819362.357912359)
# PLR_ID                                                 NaN
# gml_id                                                 NaN
# index_right                                          10228
# element_nr                            27550001_28550002.01
# strassensc                                           05855
# strassenna                                     Am Wäldchen
# str_bez                                                NaN
# strassenkl                                               V
# strassen_1                                               P
# strassen_2                                            STRA
# verkehrsri                                               B
# bezirk                                             Spandau
# stadtteil                                          Staaken
# verkehrseb                                               0
# beginnt_be                                        27550001
# endet_bei_                                        28550002
# laenge                                              533.28
# gueltig_vo                             2012-08-01 00:00:00
# okstra_id                 6DBFAF41DEB84619AFAE23D9D772A856
# distance                                        927.698856
#
#                                                    1193194  \
# NEW_OBJECTID                                       1193194
# OBJECTID                                            241755
# UIDENTSTLAE                           12220517742142516010
# ULAND                                                   12
# UREGBEZ                                                  0
# UKREIS                                                  63
# UGEMEINDE                                               56
# UJAHR                                                 2022
# UMONAT                                                   5
# USTUNDE                                                 13
# UWOCHENTAG                                               3
# UKATEGORIE                                               2
# UART                                                     8
# UTYP1                                                    7
# ULICHTVERH                                               0
# STRZUSTAND                                               0
# IstRad                                                   0
# IstPKW                                                   1
# IstFuss                                                  0
# IstKrad                                                  0
# IstGkfz                                                  0
# IstSonstige                                              0
# LINREFX                             781377,655271076015197
# LINREFY                            5825548,105126409791410
# Longitude                                        13.146658
# Latitude                                         52.507293
# Point         POINT (374215.92638902593 5819077.560675757)
# PLR_ID                                                 NaN
# gml_id                                                 NaN
# index_right                                           5102
# element_nr                            29540003_29540002.01
# strassensc                                           08046
# strassenna                            Grünanlage Hahneberg
# str_bez                                                NaN
# strassenkl                                               V
# strassen_1                                               F
# strassen_2                                            GRAL
# verkehrsri                                               B
# bezirk                                             Spandau
# stadtteil                                          Staaken
# verkehrseb                                               0
# beginnt_be                                        29540003
# endet_bei_                                        29540002
# laenge                                              113.88
# gueltig_vo                             2010-01-01 00:00:00
# okstra_id                 49CDA0D2555E48749B7364032E352500
# distance                                        945.362664
#
#                                                   1193817
# NEW_OBJECTID                                      1193817
# OBJECTID                                           242378
# UIDENTSTLAE                          12220910542121749601
# ULAND                                                  12
# UREGBEZ                                                 0
# UKREIS                                                 60
# UGEMEINDE                                             181
# UJAHR                                                2022
# UMONAT                                                  9
# USTUNDE                                                19
# UWOCHENTAG                                              7
# UKATEGORIE                                              3
# UART                                                    8
# UTYP1                                                   1
# ULICHTVERH                                              1
# STRZUSTAND                                              0
# IstRad                                                  0
# IstPKW                                                  1
# IstFuss                                                 0
# IstKrad                                                 0
# IstGkfz                                                 0
# IstSonstige                                             0
# LINREFX                            804624,077539558988065
# LINREFY                           5843595,281742690131068
# Longitude                                       13.504722
# Latitude                                        52.656556
# Point         POINT (398859.9021582735 5835115.676562948)
# PLR_ID                                                NaN
# gml_id                                                NaN
# index_right                                         15466
# element_nr                           53690004_53690005.02
# strassensc                                          41374
# strassenna                                     Hörstenweg
# str_bez                                               NaN
# strassenkl                                              V
# strassen_1                                              G
# strassen_2                                           STRA
# verkehrsri                                              B
# bezirk                                             Pankow
# stadtteil                                            Buch
# verkehrseb                                              0
# beginnt_be                                       53690004
# endet_bei_                                       53690005
# laenge                                              273.9
# gueltig_vo                            2014-09-16 00:00:00
# okstra_id                BC913E138C084BFFA314D9B263560096
# distance                                       855.523769
#
# [47 rows x 104625 columns]

# %%
final_df = nearest_line.drop(columns=['Point','index_right', 'element_nr', 'strassenna', 'str_bez', 'strassenkl', 'strassen_1',
       'strassen_2', 'verkehrsri', 'bezirk', 'stadtteil', 'verkehrseb',
       'beginnt_be', 'endet_bei_', 'laenge', 'gueltig_vo'])

# %%
final_df
# Out:
#          NEW_OBJECTID  OBJECTID           UIDENTSTLAE  ULAND  UREGBEZ  UKREIS  \
# 59914           59914     59915                  None     12        0      72
# 61617           61617     61618                  None     12        0      72
# 61720           61720     61721                  None     12        0      72
# 61784           61784     61785                  None     12        0      72
# 62219           62219     62220                  None     12        0      72
# ...               ...       ...                   ...    ...      ...     ...
# 1192399       1192399    240960  11221205110000003490     11        0       9
# 1192409       1192409    240970  11221221110000070490     11        0       9
# 1192490       1192490    241051  12220518742142519960     12        0      63
# 1193194       1193194    241755  12220517742142516010     12        0      63
# 1193817       1193817    242378  12220910542121749601     12        0      60
#
#          UGEMEINDE  UJAHR  UMONAT  USTUNDE  ...  IstSonstige  \
# 59914           17   2018       1       14  ...            0
# 61617           17   2018       4       21  ...            0
# 61720           17   2018       6       19  ...            0
# 61784           17   2018       5       11  ...            0
# 62219           17   2018       5       16  ...            0
# ...            ...    ...     ...      ...  ...          ...
# 1192399          9   2022      12       12  ...            0
# 1192409          9   2022      12        1  ...            0
# 1192490         56   2022       5       10  ...            0
# 1193194         56   2022       5       13  ...            0
# 1193817        181   2022       9       19  ...            0
#
#                         LINREFX                  LINREFY  Longitude  \
# 59914    800009,585300000040000  5809193,854399999600000  13.405709
# 61617    800350,154199999990000  5811043,602800000500000  13.412349
# 61720    800364,173300000020000  5810821,521700000400000  13.412355
# 61784    800164,719200000050000  5809958,096900000200000  13.408663
# 62219    799976,104500000020000  5806920,706000000200000  13.403191
# ...                         ...                      ...        ...
# 1192399  809343,908464691019617  5819391,039504010230303  13.551736
# 1192409  809561,533233260037377  5815852,167966020293534  13.551654
# 1192490  780311,331294378964230  5825745,262098999693990  13.131154
# 1193194  781377,655271076015197  5825548,105126409791410  13.146658
# 1193817  804624,077539558988065  5843595,281742690131068  13.504722
#
#           Latitude    PLR_ID            gml_id  strassensc  \
# 59914    52.350773       NaN               NaN       04159
# 61617    52.367167       NaN               NaN       04159
# 61720    52.365169       NaN               NaN       04159
# 61784    52.357539       NaN               NaN       04159
# 62219    52.330415       NaN               NaN       04159
# ...            ...       ...               ...         ...
# 1192399  52.436978  09200717  re_ortsteil.0907       44817
# 1192409  52.405139  09300921  re_ortsteil.0906       40386
# 1192490  52.509610       NaN               NaN       05855
# 1193194  52.507293       NaN               NaN       08046
# 1193817  52.656556       NaN               NaN       41374
#
#                                 okstra_id     distance
# 59914    B0BA1D4FB553446AB4123C3953A5FBB6  2900.757961
# 61617    B0BA1D4FB553446AB4123C3953A5FBB6  1066.457522
# 61720    B0BA1D4FB553446AB4123C3953A5FBB6  1287.483729
# 61784    B0BA1D4FB553446AB4123C3953A5FBB6  2133.476843
# 62219    B0BA1D4FB553446AB4123C3953A5FBB6  5171.129917
# ...                                   ...          ...
# 1192399  47E73B0EDC5E43F2A9A0B7331E42605E     0.797230
# 1192409  91AC0738AB5140F1A5EAE93C2B38BFC0     0.496318
# 1192490  6DBFAF41DEB84619AFAE23D9D772A856   927.698856
# 1193194  49CDA0D2555E48749B7364032E352500   945.362664
# 1193817  BC913E138C084BFFA314D9B263560096   855.523769
#
# [104625 rows x 31 columns]

# %%
final_df = final_df[final_df['PLR_ID'].notna()| final_df['PLR_ID'].isna() & (final_df['ULAND'] == 11)  ]

# %%
def combine_ist_columns(row):
    parts = []
    if row['IstRad'] == 1:
        parts.append('Bike')
    if row['IstPKW'] == 1:
        parts.append('Car')
    if row['IstFuss'] == 1:
        parts.append('Pedestrian')
    if row['IstKrad'] == 1:
        parts.append('Motorcycle')
    if row['IstGkfz'] == 1:
        parts.append('Truck')
    if row['IstSonstige'] == 1:
        parts.append('Other')

    return '-'.join(parts)

# Anwenden der Funktion auf jede Zeile des DataFrame
final_df['Accident_Part'] = final_df.apply(combine_ist_columns, axis=1)

print(final_df[['Accident_Part']])
# Out:
#                      Accident_Part
# 203811                         Car
# 115789              Car-Motorcycle
# 263213                    Bike-Car
# 485470              Car-Pedestrian
# 485775                         Car
# ...                            ...
# 1192347                   Bike-Car
# 1192364  Car-Pedestrian-Motorcycle
# 1192384                   Bike-Car
# 1192399                       Bike
# 1192409                        Car
#
# [62489 rows x 1 columns]
# C:\Users\Domen\AppData\Local\Temp\ipykernel_11868\3348557609.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['Accident_Part'] = final_df.apply(combine_ist_columns, axis=1)

# %%
final_df.to_csv('../data/tableau/berlin_accidents.csv', index = False)

# %%
final_df
# Out:
#          NEW_OBJECTID  OBJECTID           UIDENTSTLAE  ULAND  UREGBEZ  UKREIS  \
# 203811         203811    203812                  None     11        0       9
# 115789         115789    115790                  None     11        0       7
# 263213         263213     51346                  None     11        0       7
# 485470         485470      5233  11201130110000095232     11        0       7
# 485775         485775      5538  11200818110000052224     11        0       7
# ...               ...       ...                   ...    ...      ...     ...
# 1192347       1192347    240908  11221216110000055010     11        0       7
# 1192364       1192364    240925  11221211110000035690     11        0       2
# 1192384       1192384    240945  11221204110000001840     11        0      10
# 1192399       1192399    240960  11221205110000003490     11        0       9
# 1192409       1192409    240970  11221221110000070490     11        0       9
#
#          UGEMEINDE  UJAHR  UMONAT  USTUNDE  ...                 LINREFX  \
# 203811           9   2018       8       23  ...  819516,089599999950000
# 115789           7   2018       5       12  ...  800514,550000000050000
# 263213           7   2019       7        7  ...  800561,615819145930000
# 485470           7   2020      11        7  ...  800643,464499999770000
# 485775           7   2020       8       10  ...  800656,300499999900000
# ...            ...    ...     ...      ...  ...                     ...
# 1192347          7   2022      12       21  ...  795108,988904246012680
# 1192364          2   2022      12       19  ...  802872,233382713980973
# 1192384         10   2022      12       13  ...  811285,425559094990604
# 1192399          9   2022      12       12  ...  809343,908464691019617
# 1192409          9   2022      12        1  ...  809561,533233260037377
#
#                          LINREFY  Longitude   Latitude    PLR_ID  \
# 203811   5812746,894799999900000  13.694536  52.371599  09301228
# 115789   5812371,809799999900000  13.415946  52.378983  07601547
# 263213   5812278,850960796700000  13.416552  52.378124  07601547
# 485470   5812139,257799999800000  13.417626  52.376828  07601547
# 485775   5812092,049900000900000  13.417771  52.376398  07601547
# ...                          ...        ...        ...       ...
# 1192347  5825297,404789079912007  13.348176  52.497791  07100102
# 1192364  5827260,776961119845510  13.463974  52.511136  02500831
# 1192384  5827736,249232850037515  13.587993  52.510661  10400836
# 1192399  5819391,039504010230303  13.551736  52.436978  09200717
# 1192409  5815852,167966020293534  13.551654  52.405139  09300921
#
#                    gml_id  strassensc                         okstra_id  \
# 203811   re_ortsteil.0915       43538  1481C3A8E9DE495F929CDAA2FCF81A26
# 115789   re_ortsteil.0706       02410  01BCF480BB8B4F1AAE17EC812E441054
# 263213   re_ortsteil.0706       02410  01BCF480BB8B4F1AAE17EC812E441054
# 485470   re_ortsteil.0706       02410  01BCF480BB8B4F1AAE17EC812E441054
# 485775   re_ortsteil.0706       02410  01BCF480BB8B4F1AAE17EC812E441054
# ...                   ...         ...                               ...
# 1192347  re_ortsteil.0701       03133  098DB65843EE4854B71042CAF601929B
# 1192364  re_ortsteil.0201       43540  28B9526C492F4FD0AF54EB226BFB4512
# 1192384  re_ortsteil.1003       42265  B323335ABB8245E6B673E24A3CCFBFCF
# 1192399  re_ortsteil.0907       44817  47E73B0EDC5E43F2A9A0B7331E42605E
# 1192409  re_ortsteil.0906       40386  91AC0738AB5140F1A5EAE93C2B38BFC0
#
#          distance              Accident_Part
# 203811   0.327541                        Car
# 115789   5.111999             Car-Motorcycle
# 263213   5.327790                   Bike-Car
# 485470   4.548801             Car-Pedestrian
# 485775   5.362554                        Car
# ...           ...                        ...
# 1192347  0.357513                   Bike-Car
# 1192364  0.654043  Car-Pedestrian-Motorcycle
# 1192384  0.055987                   Bike-Car
# 1192399  0.797230                       Bike
# 1192409  0.496318                        Car
#
# [62489 rows x 32 columns]

# %%
final_df.dtypes
# Out:
# NEW_OBJECTID       int64
# OBJECTID           int64
# UIDENTSTLAE       object
# ULAND              int64
# UREGBEZ            int64
# UKREIS             int64
# UGEMEINDE          int64
# UJAHR              int64
# UMONAT             int64
# USTUNDE            int64
# UWOCHENTAG         int64
# UKATEGORIE         int64
# UART               int64
# UTYP1              int64
# ULICHTVERH         int64
# STRZUSTAND         int64
# IstRad             int64
# IstPKW             int64
# IstFuss            int64
# IstKrad            int64
# IstGkfz            int64
# IstSonstige        int64
# LINREFX           object
# LINREFY           object
# Longitude        float64
# Latitude         float64
# PLR_ID            object
# gml_id            object
# strassensc        object
# okstra_id         object
# distance         float64
# Accident_Part     object
# dtype: object

# %%
import pymysql 
from sqlalchemy import create_engine
from sqlalchemy import Integer, DateTime, Text, Float
import json

# %%
with open("../config/secret.json", 'r') as f:
    secret = json.load(f)
    
SQL_secret = secret["PASSWORD"]
table_name_1 = "verkehrsunfaelle"

# %%
connection_string = 'mysql+pymysql://root:'+SQL_secret+'@localhost/berlin_accident'
engine = create_engine(connection_string)

# %%
final_df.to_sql(table_name_1, con=engine, if_exists='replace', index=False,
        dtype = {
        "NEW_OBJECTID": Integer,
        "OBJECTID": Integer,
        "UIDENTSTLAE": Text,
        "ULAND": Integer,
        "UREGBEZ": Integer,
        "UKREIS": Integer,
        "UGEMEINDE": Integer,
        "UJAHR": Integer,
        "UMONAT": Integer,
        "USTUNDE": Integer,
        "UWOCHENTAG": Integer,
        "UKATEGORIE": Integer,
        "UART": Integer,
        "UTYP1": Integer,
        "ULICHTVERH": Integer,
        "STRZUSTAND": Integer,
        "IstRad": Integer,
        "IstPKW": Integer,
        "IstFuss": Integer,
        "IstKrad": Integer,
        "IstGkfz": Integer,
        "IstSonstige": Integer,
        "LINREFX": Text,
        "LINREFY": Text,
        "Longitude": Float,
        "Latitude": Float,
        "PLR_ID": Text,
        "gml_id": Text,
        "strassensc": Text,
        "distance": Float,
        "Accident_Part":Text,
        "okstra_id":Text

    })
# Out:
# 62489
